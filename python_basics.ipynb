# %% [markdown]
# <a href="https://colab.research.google.com/github/prasannaramuvj/python_practice/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day-**1**
# Topics: Variables, Data Types, Operators, Syntax
#
# Key Concepts:
# **Variables** & **Naming** **Conventions**
#
# How to declare and assign variables
# PEP 8 naming standards (snake_case)
# Dynamic typing in Python
#
# **Data** Types
# int (integers: 5, -10, 0)
# float (decimals: 3.14, -2.5)
# str (strings: "Hello", 'World')
# bool (True, False)
# Type checking with type()
#
# **Operators**
# Arithmetic: +, -, *, /, //, %, **
# Comparison: ==, !=, >, <, >=, <=
# Logical: and, or, not
# Assignment: =, +=, -=, *=, /=
#
# **Basic Syntax**
# Indentation (crucial!)
# Comments (# and ''' ''')
# Print and input functions

# %%
a = 5
b = "prasanna"
c = "a"
d = 4.5
e = True
print(a,b,c,d,e)
print(type(a),type(b),type(c))
# Out:
# 5 prasanna a 4.5 True
# <class 'int'> <class 'str'> <class 'str'>
